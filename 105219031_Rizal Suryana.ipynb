# %%
#matplotlib
import matplotlib.pyplot as plt
import numpy as np

#seaborn
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# NAMA: RIZAL SURYANA
# NIM : 105219031
# MODUL 4

# %%
#generate data random
x = np.random.normal(0, 0.1, 100)
y = np.random.normal(0, 0.1, 100)

#plot
plt.plot(x,y, 'o'); #o adalah markernya utk mghbungkn x dan y, bisa '*', 
plt.show()

# %%
# ?plt.plot #menegcek dokumentasi

# %%
#generate data random
x = np.random.normal(0, 0.1, 100)
y = np.random.normal(0, 0.1, 100)

#plot
plt.plot(x,y, marker = 'o'); #o adalah markernya utk mghbungkn x dan y
plt.show()

# %%
z = x**2
plt.plot(x, z)

# %%
x = ['Januari', 'Feb', 'Mar']
z = [100, 500, 2000]
plt.plot(x, z, '')

# %%
l = np.linspace(0,10,100)
a = np.sin(l)
plt.plot(l,a)

# %%
x = ['Januari', 'Feb', 'Mar']
z1 = [100, 500, 2000]
z2 = [200, 600, 3000]
z3 = [50, 400, 4000]

plt.plot(x, z1)
plt.plot(x, z2)
plt.plot(x, z3)

# %%
#generate data integer secara random
x = np.random.randint(1000, size=100)

#histogram
plt.hist(x)
plt.show()

# %%
x = ['Januari', 'Feb', 'Mar']
z1 = [100, 500, 2000]

plt.barh(x, z1)
plt.show()

# %%
x = ['Januari', 'Feb', 'Mar']
z1 = [100, 500, 2000]

plt.bar(x, z1)
plt.show()

# %%
x = np.random.randint(1000, size=100)
plt.boxplot(x)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f331a028590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3319fb0610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3319fb6650>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3319fb6110>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f331a028b50>,
#   <matplotlib.lines.Line2D at 0x7f3319fb00d0>]}

# %%
x = ['Januari', 'Feb', 'Mar']
z1 = [100, 500, 2000]
z2 = [200, 600, 3000]
z3 = [50, 400, 4000]

plt.plot(x, z1)
plt.plot(x, z2)
plt.plot(x, z3)

#tambahkan grid
plt.grid(True)

#tambahkan title
plt.title('kasus positif tiap bulan di 3 daerah')
# Out:
# Text(0.5, 1.0, 'kasus positif tiap bulan di 3 daerah')

# %%
#tittle
plt.title('Kasus Positif tiap bulan di 3 daerah')

#label
plt.xlabel('Bulan')
plt.ylabel('Kasus Positif')

#menambahkan legend
plt.legend(['Jakarta', 'Bandung', 'Semarang'])

#menampilkan

# %%
tips = sns.load_dataset("tips")

# %%
sns.displot(data=tips, x='total_bill')

# %%
sns.displot(data=tips, x='total_bill', col='time')

# %%
set(tips.smoker)
# Out:
# {'No', 'Yes'}

# %%
tips.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]>

# %%
sns.displot(data=tips, x='total_bill', col='time', hue='smoker')

# %%
sns.displot(tips['total_bill'], kde=True)

# %%
sns.countplot(tips['sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(tips)
