# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data-Kebakaran.csv")
print(df)
# Out:
#     tanggal_kejadian                                    lokasi_kejadian  \
# 0           5/5/2017  Jl. Kembang 3  RT. 08 RW. 01 Kel. Senen Kec. S...
# 1           5/9/2017  Jl. Penjernihan 1 RT.05 RW. 07 Kel. Bendungan ...
# 2          5/27/2017  Jl. M. Ali I No.51 RT. 09 RW. 03 Kel. Tanah Ti...
# 3          5/28/2017   Jl. Rasa Mulya No.4 RT. 03 RW. 08 Kel. Bungur...
# 4           5/2/2017  Jl. Indokarya 4 Blok D No. 1 Kel. Papanggo Kec...
# ..               ...                                                ...
# 350       10/19/2017                            Jl. Mabes TNI Cilangkap
# 351       10/20/2017                                Jl. Bojong Rangkong
# 352       10/21/2017       Jl. Perintis Kemerdekaan No.38 Rt.008 Rw.001
# 353       10/27/2017  Jl. Dewi Sartika Gg. Tanjung Sanyang RT. 01 RW...
# 354       10/31/2017  Jl. Supriyadi Rt.04/04 (Titik Kenal Depan Term...
#
#            wilayah  jumlah_sarana_rusak  \
# 0    Jakarta Pusat                    1
# ...

# %%
display(df)
# Out:
#     tanggal_kejadian                                    lokasi_kejadian  \
# 0           5/5/2017  Jl. Kembang 3  RT. 08 RW. 01 Kel. Senen Kec. S...
# 1           5/9/2017  Jl. Penjernihan 1 RT.05 RW. 07 Kel. Bendungan ...
# 2          5/27/2017  Jl. M. Ali I No.51 RT. 09 RW. 03 Kel. Tanah Ti...
# 3          5/28/2017   Jl. Rasa Mulya No.4 RT. 03 RW. 08 Kel. Bungur...
# 4           5/2/2017  Jl. Indokarya 4 Blok D No. 1 Kel. Papanggo Kec...
# ..               ...                                                ...
# 350       10/19/2017                            Jl. Mabes TNI Cilangkap
# 351       10/20/2017                                Jl. Bojong Rangkong
# 352       10/21/2017       Jl. Perintis Kemerdekaan No.38 Rt.008 Rw.001
# 353       10/27/2017  Jl. Dewi Sartika Gg. Tanjung Sanyang RT. 01 RW...
# 354       10/31/2017  Jl. Supriyadi Rt.04/04 (Titik Kenal Depan Term...
#
#            wilayah  jumlah_sarana_rusak  \
# 0    Jakarta Pusat                    1
# ...

# %%
global str
a = df2['jumlah_sarana_rusak']
b = df2['tanggal_kejadian']
fig = plt.figure(figsize=(15, 15))
plt.bar(b,a, label="TOTAL SARANA RUSAK")
plt.legend()
plt.ylabel('sarana rusak')
plt.xlabel('waktu kejadian')
plt.show()

# %%
wilayah = df['wilayah']
x = df['jumlah_sarana_rusak'] 
fig = plt.figure(figsize=(15, 15))
plt.title("TOTAL SARANA RUSAK PERWILAYAH")
plt.xlabel("Sarana Rusak")
plt.ylabel("Wilayah")
plt.yticks(rotation=90)
plt.barh(wilayah, x)
plt.show()

# %%
SaranaRusak = df['jumlah_sarana_rusak']
ax = sns.boxplot(SaranaRusak)
plt.grid(True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
wilayah = df['wilayah']
x = df['jumlah_sarana_rusak'] 
fig = plt.figure(figsize=(15, 15))
plt.title("TOTAL SARANA RUSAK PERWILAYAH")
plt.ylabel("Sarana Rusak")
plt.xlabel("Wilayah")
plt.scatter(wilayah, x)
plt.show()

# %%
wilayah = df2['jumlah_sarana_rusak']
plt.title("TOTAL SARANA RUSAK")
plt.plot(wilayah,np.arange(1,22))
plt.grid(True)
plt.show()
